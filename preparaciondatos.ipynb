# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import LabelEncoder
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("Cars export 2025-02-05 19-38-54.csv")

df
# Out:
#            model  year   price transmission  mileage fuelType  tax   mpg  \
# 0        G Class  2020  159999    Semi-Auto     1350   Petrol  145  21.4
# 1        G Class  2020  154998    Automatic     3000   Petrol  150  21.4
# 2       SL CLASS  2011  149948    Automatic     3000   Petrol  570  21.4
# 3             R8  2020  145000    Semi-Auto     2000   Petrol  145  21.1
# 4        A Class  2019  140319    Semi-Auto      785   Petrol  150  22.1
# ...          ...   ...     ...          ...      ...      ...  ...   ...
# 97707      Corsa  2003     590       Manual    82000   Petrol  160  44.8
# 97708      Focus  2003     495       Manual   177644   Petrol  200  41.5
# 97709      Corsa  2002     495       Manual    99842   Petrol  145  50.4
# 97710      Astra  2001     450       Manual   159000   Petrol  235  40.4
# 97711      Agila  2003     450       Manual    90000   Petrol  205  43.5
#
#        engineSize Manufacturer
# 0             4.0         merc
# 1             4.0         merc
# 2             6.2         merc
# 3             5.2         Audi
# 4             4.0         merc
# ...           ...          ...
# 97707         1.2     vauxhall
# 97708         1.6         ford
# 97709         1.0     vauxhall
# 97710         1.6     vauxhall
# 97711         1.2     vauxhall
#
# [97712 rows x 10 columns]

# %%
#df.head()

pd.set_option("display.max_columns", 20)
pd.set_option("display.max_rows", 20)


pd.get_dummies(df['year'])
# Out:
#         1970   1996   1997   1998   1999   2000   2001   2002   2003   2004  \
# 0      False  False  False  False  False  False  False  False  False  False
# 1      False  False  False  False  False  False  False  False  False  False
# 2      False  False  False  False  False  False  False  False  False  False
# 3      False  False  False  False  False  False  False  False  False  False
# 4      False  False  False  False  False  False  False  False  False  False
# ...      ...    ...    ...    ...    ...    ...    ...    ...    ...    ...
# 97707  False  False  False  False  False  False  False  False   True  False
# 97708  False  False  False  False  False  False  False  False   True  False
# 97709  False  False  False  False  False  False  False   True  False  False
# 97710  False  False  False  False  False  False   True  False  False  False
# 97711  False  False  False  False  False  False  False  False   True  False
#
#        ...   2012   2013   2014   2015   2016   2017   2018   2019   2020  \
# 0      ...  False  False  False  False  False  False  False  False   True
# 1      ...  False  False  False  False  False  False  False  False   True
# 2      ...  False  False  False  False  False  False  False  False  False
# 3      ...  False  False  False  False  False  False  False  False   True
# 4      ...  False  False  False  False  False  False  False   True  False
# ...    ...    ...    ...    ...    ...    ...    ...    ...    ...    ...
# 97707  ...  False  False  False  False  False  False  False  False  False
# 97708  ...  False  False  False  False  False  False  False  False  False
# 97709  ...  False  False  False  False  False  False  False  False  False
# 97710  ...  False  False  False  False  False  False  False  False  False
# 97711  ...  False  False  False  False  False  False  False  False  False
#
#         2024
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
# ...      ...
# 97707  False
# 97708  False
# 97709  False
# 97710  False
# 97711  False
#
# [97712 rows x 27 columns]

# %%
""" label_encoder = LabelEncoder()

df['encoder'] = label_encoder.fit_transform(df['model'])

df """
df_numerico=df.select_dtypes(include=[np.number])

corr=df_numerico.corr()

print(corr)
# Out:
#                 year     price   mileage       tax       mpg  engineSize
# year        1.000000  0.492491 -0.739664  0.192058 -0.130547   -0.035639
# price       0.492491  1.000000 -0.417996  0.307003 -0.295507    0.639356
# mileage    -0.739664 -0.417996  1.000000 -0.215558  0.183070    0.107299
# tax         0.192058  0.307003 -0.215558  1.000000 -0.451370    0.280770
# mpg        -0.130547 -0.295507  0.183070 -0.451370  1.000000   -0.249346
# engineSize -0.035639  0.639356  0.107299  0.280770 -0.249346    1.000000

# %%
plt.figure(figsize=(8,6))
sns.heatmap(corr, annot=True, cmap="coolwarm", fmt=".2f", linewidths=0.5)
plt.title("Matriz de Correlación")
plt.show()

# %%
df
# Out:
#            model  year   price transmission  mileage fuelType  tax   mpg  \
# 0        G Class  2020  159999    Semi-Auto     1350   Petrol  145  21.4
# 1        G Class  2020  154998    Automatic     3000   Petrol  150  21.4
# 2       SL CLASS  2011  149948    Automatic     3000   Petrol  570  21.4
# 3             R8  2020  145000    Semi-Auto     2000   Petrol  145  21.1
# 4        A Class  2019  140319    Semi-Auto      785   Petrol  150  22.1
# ...          ...   ...     ...          ...      ...      ...  ...   ...
# 97707      Corsa  2003     590       Manual    82000   Petrol  160  44.8
# 97708      Focus  2003     495       Manual   177644   Petrol  200  41.5
# 97709      Corsa  2002     495       Manual    99842   Petrol  145  50.4
# 97710      Astra  2001     450       Manual   159000   Petrol  235  40.4
# 97711      Agila  2003     450       Manual    90000   Petrol  205  43.5
#
#        engineSize Manufacturer
# 0             4.0         merc
# 1             4.0         merc
# 2             6.2         merc
# 3             5.2         Audi
# 4             4.0         merc
# ...           ...          ...
# 97707         1.2     vauxhall
# 97708         1.6         ford
# 97709         1.0     vauxhall
# 97710         1.6     vauxhall
# 97711         1.2     vauxhall
#
# [97712 rows x 10 columns]

# %%
duplicados= df.duplicated()
print(duplicados)

df_sin_duplicados = df.drop_duplicates()
print(df_sin_duplicados)
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 97707    False
# 97708    False
# 97709    False
# 97710    False
# 97711    False
# Length: 97712, dtype: bool
#            model  year   price transmission  mileage fuelType  tax   mpg  \
# 0        G Class  2020  159999    Semi-Auto     1350   Petrol  145  21.4
# 1        G Class  2020  154998    Automatic     3000   Petrol  150  21.4
# 2       SL CLASS  2011  149948    Automatic     3000   Petrol  570  21.4
# 3             R8  2020  145000    Semi-Auto     2000   Petrol  145  21.1
# 4        A Class  2019  140319    Semi-Auto      785   Petrol  150  22.1
# ...          ...   ...     ...          ...      ...      ...  ...   ...
# 97707      Corsa  2003     590       Manual    82000   Petrol  160  44.8
# 97708      Focus  2003     495       Manual   177644   Petrol  200  41.5
# 97709      Corsa  2002     495       Manual    99842   Petrol  145  50.4
# 97710      Astra  2001     450       Manual   159000   Petrol  235  40.4
# 97711      Agila  2003     450       Manual    90000   Petrol  205  43.5
#
#        engineSize Manufacturer
# 0             4.0         merc
# 1             4.0         merc
# 2             6.2         merc
# 3             5.2         Audi
# 4             4.0         merc
# ...           ...          ...
# 97707         1.2     vauxhall
# 97708         1.6         ford
# 97709         1.0     vauxhall
# 97710         1.6     vauxhall
# 97711         1.2     vauxhall
#
# [97712 rows x 10 columns]
